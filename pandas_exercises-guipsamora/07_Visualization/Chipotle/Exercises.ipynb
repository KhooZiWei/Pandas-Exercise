# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(url, sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
top_5 = chipo.groupby('item_name').quantity.sum().reset_index().sort_values(by='quantity', ascending=False).head(5)
top_5
# Out:
#               item_name  quantity
# 17         Chicken Bowl       761
# 18      Chicken Burrito       591
# 25  Chips and Guacamole       506
# 39        Steak Burrito       386
# 10    Canned Soft Drink       351

# %%
# create the plot
top_5.plot(kind='bar', x='item_name', y='quantity', legend=False, xlabel='Items', ylabel='Number of Times Ordered', title="Most ordered Chipotle's Items")

# show the plot
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
items_price = chipo.groupby('order_id').agg({'item_price': 'sum', 'quantity': 'sum'}).reset_index()
items_price.head()
# Out:
#    order_id  item_price  quantity
# 0         1       11.56         4
# 1         2       16.98         2
# 2         3       12.67         2
# 3         4       21.00         2
# 4         5       13.70         2

# %%
# create the plot
plt.scatter(x=items_price.item_price, y=items_price.quantity)
plt.xlabel('Price')
plt.ylabel('Items Orderred')

# show the plot
plt.show()
